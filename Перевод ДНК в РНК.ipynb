# %% [markdown]
# https://rosalind.info/problems/rna/
#
# Дано: последовательность нуклеотидов ДНК (t).
#
# Нужно: построить соответствующую (не комплементарную) цепь РНК (u), в которой бы вместо тимина был урацил.
#
# В ответ вывести строку РНК (u)

# %%
t = '...'
u = ''
   
for sym in t: # цикл по символам строки t
    if sym == 'T':
        u = u + 'U'
    else: 
        u = u + sym    

print(u)
# Out:
# ...
