# %% [markdown]
# Дано: последовательность нуклеотидов ДНК (строка)
#
# Нужно: подсчитать количество каждого из нуклеотидов в цепи ДНК, полученные числа в ответе вывести через пробел
#
# https://rosalind.info/problems/dna/

# %%
s = '...'

symbol_list = ['A', 'C', 'G', 'T']

count = {'A' : 0, 'C' : 0, 'T' : 0, 'G' : 0}

for i in range(len(s)):
    for j in symbol_list:
        if s[i] == j:
            count[j] += 1
            
#print(count)

for j in symbol_list:
    print(count[j], end=' ')
# Out:
# 250 253 228 250

# %% [markdown]
# Более компактный вариант решения:

# %%
s = '...'

symbol_list = ['A', 'C', 'G', 'T']

for sym in symbol_list:
    print(s.count(sym), end=' ')
# Out:
# 250 253 228 250
