# %% [markdown]
# Дано: строка ДНК (s)
# Получить: комплементарную ДНК (s_c)

# %%
s = '...'
s_inv = s[::-1] # цепь в обратном порядке
s_c = '' # цепь, в которую мы будем добавлять комплементарные нуклеотиды

for sym in s_inv:
    if sym == 'A':
        s_c = s_c + 'T'
        continue
    if sym == 'T':
        s_c = s_c + 'A'
        continue
    if sym == 'G':
        s_c = s_c + 'C'
        continue
    if sym == 'C':
        s_c = s_c + 'G'        

 
print(s_c)
# Out:
# ...
